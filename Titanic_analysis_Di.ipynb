# %% [markdown]
# <!--Collapsible Headings-->
# ## EDA of Titanic dataset by DiMoriarty
#
#
# Legends
# - Survival - Survival (0 = No; 1 = Yes). Not included in test.csv file.
# - Pclass - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - Name - Name
# - Sex - Sex
# - Age - Age
# - Sibsp - Number of Siblings/Spouses Aboard
# - Parch - Number of Parents/Children Aboard
# - Ticket - Ticket Number
# - Fare - Passenger Fare
# - Deck - A/B/C/D/E/F/G
# - Embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# - Who - man/woman/child
# - Alive - yes/no
# - Alone - True/False

# %%
import pandas as pd
import numpy as np
from numpy.random import randn, randint, uniform, sample
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from numpy.random import randn, randint, uniform, sample
from pandas.plotting import scatter_matrix
pd.set_option('display.max_rows', 20)
fig=plt.figure(figsize=[1,1],dpi=30)
import plotly as py
from plotly.offline import iplot
import cufflinks as cf
cmap = plt.get_cmap('tab20c')
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning:
#
# Blowfish has been deprecated

# %%
_df_0=sns.load_dataset('titanic')
_df_0.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 439         0       2    male  31.0      0      0   10.5000        S  Second
# 173         0       3    male  21.0      0      0    7.9250        S   Third
# 806         0       1    male  39.0      0      0    0.0000        S   First
# 297         0       1  female   2.0      1      2  151.5500        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 609         1       1  female  40.0      0      0  153.4625        S   First
# 678         0       3  female  43.0      1      6   46.9000        S   Third
# 651         1       2  female  18.0      0      1   23.0000        S  Second
# 255         1       3  female  29.0      0      2   15.2458        C   Third
# 76          0       3    male   NaN      0      0    7.8958        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 439    man        True  NaN  Southampton    no   True
# ...

# %%
_cols=_df_0.columns
_desc=_df_0.describe()

# %%
_desc
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
_df_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# <!--Collapsible Headings-->
# ## Heatmap
#
#
# Legends
# - Survival - Survival (0 = No; 1 = Yes). Not included in test.csv file.
# - Pclass - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - Name - Name
# - Sex - Sex
# - Age - Age
# - Sibsp - Number of Siblings/Spouses Aboard
# - Parch - Number of Parents/Children Aboard
# - Ticket - Ticket Number
# - Fare - Passenger Fare
# - Deck - A/B/C/D/E/F/G
# - Embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# - Who - man/woman/child
# - Alive - yes/no
# - Alone - True/False

# %% [markdown]
# ##Null values

# %%
_df_0.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.heatmap(_df_0.isnull(),cmap='Blues')
# Out:
# <Axes: >

# %%
_cor=_df_0.corr(numeric_only=True)
_cor
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(data=_cor,cmap='inferno')
# Out:
# <Axes: >

# %% [markdown]
# <!--Collapsible Headings-->
# ## Univarient analysis
#
# Legends
# - Survival - Survival (0 = No; 1 = Yes). Not included in test.csv file.
# - Pclass - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - Name - Name
# - Sex - Sex
# - Age - Age
# - Sibsp - Number of Siblings/Spouses Aboard
# - Parch - Number of Parents/Children Aboard
# - Ticket - Ticket Number
# - Fare - Passenger Fare
# - Deck - A/B/C/D/E/F/G
# - Embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# - Who - man/woman/child
# - Alive - yes/no
# - Alone - True/False

# %%
_desc
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
q=_df_0['parch']
y_deck=np.linspace(0,60,10,endpoint=False)
q
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    2
# 889    0
# 890    0
# Name: parch, Length: 891, dtype: int64

# %%
fig, ax = plt.subplots(1, 5, figsize = (15, 5))
ax[0].hist(_df_0['survived'],color='red')
ax[0].set_xlabel('survived')
ax[1].hist(_df_0['pclass'],color='violet')
ax[1].set_xlabel('pclass')
ax[2].hist(_df_0['age'],stacked=False,color='brown')
ax[2].set_xlabel('age')
ax[2].set_xticks([0,10,20,30,40,50,60,70,80])
ax[3].hist(_df_0['sibsp'],color='yellow')
ax[3].set_xlabel('sibsp')
ax[3].set_xticks([0,1,2,3,4,5,6,7,8])
ax[4].hist(_df_0['fare'].value_counts())
ax[4].set_xlabel('fare')
plt.tight_layout()

# %% [markdown]
# <!--Collapsible Headings-->
# ## Survived
#
# Legends
# - Survival - Survival (0 = No; 1 = Yes). Not included in test.csv file.
# - Pclass - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - Name - Name
# - Sex - Sex
# - Age - Age
# - Sibsp - Number of Siblings/Spouses Aboard
# - Parch - Number of Parents/Children Aboard
# - Ticket - Ticket Number
# - Fare - Passenger Fare
# - Deck - A/B/C/D/E/F/G
# - Embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# - Who - man/woman/child
# - Alive - yes/no
# - Alone - True/False

# %%
_df_0['survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
_df_0['survived'].describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: survived, dtype: float64

# %%
sns.countplot(data=_df_0,x='survived')
plt.title('Survived')
plt.show()

# %%
_ex=[0,.05]
_df_0['survived'].value_counts().plot.pie(autopct='%.3f',explode=_ex)
plt.show()

# %% [markdown]
# <!--Collapsible Headings-->
# ##  Pclass
#
# Legends
# - Survival - Survival (0 = No; 1 = Yes). Not included in test.csv file.
# - Pclass - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - Name - Name
# - Sex - Sex
# - Age - Age
# - Sibsp - Number of Siblings/Spouses Aboard
# - Parch - Number of Parents/Children Aboard
# - Ticket - Ticket Number
# - Fare - Passenger Fare
# - Deck - A/B/C/D/E/F/G
# - Embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# - Who - man/woman/child
# - Alive - yes/no
# - Alone - True/False

# %%
_df_0['pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: pclass, dtype: int64

# %%
_ex=[0,0.03,0.05]
_df_0['pclass'].value_counts().plot.pie(autopct='%.3f',explode=_ex)
plt.show()

# %%
sns.countplot(x='pclass', data = _df_0)
plt.show()

# %%
x=_df_0.groupby(['pclass', 'survived'])['survived'].count()
x
# Out:
# pclass  survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: survived, dtype: int64

# %%
sns.countplot(x='pclass',data=_df_0,hue='survived')
plt.show()

# %%
sns.catplot(x='pclass',y='survived',data=_df_0,hue='sex',kind='bar')
plt.grid(True)
plt.show()

# %% [markdown]
# <!--Collapsible Headings-->
# ##  Sex
#
# Legends
# - Survival - Survival (0 = No; 1 = Yes). Not included in test.csv file.
# - Pclass - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - Name - Name
# - Sex - Sex
# - Age - Age
# - Sibsp - Number of Siblings/Spouses Aboard
# - Parch - Number of Parents/Children Aboard
# - Ticket - Ticket Number
# - Fare - Passenger Fare
# - Deck - A/B/C/D/E/F/G
# - Embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# - Who - man/woman/child
# - Alive - yes/no
# - Alone - True/False

# %%
_df_0.groupby(['sex','survived'])['pclass'].value_counts()
# Out:
# sex     survived  pclass
# female  0         3          72
#                   2           6
#                   1           3
#         1         1          91
#                   3          72
#                   2          70
# male    0         3         300
#                   2          91
#                   1          77
#         1         3          47
#                   1          45
#                   2          17
# Name: pclass, dtype: int64

# %%
_df_0.groupby(['sex'])['survived'].value_counts()
# Out:
# sex     survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: survived, dtype: int64

# %%
_df_0.groupby(['sex'])['pclass'].value_counts()
# Out:
# sex     pclass
# female  3         144
#         1          94
#         2          76
# male    3         347
#         1         122
#         2         108
# Name: pclass, dtype: int64

# %%
_df_0['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
ex=[0,.07]
_df_0['sex'].value_counts().plot.pie(autopct='%.3f',explode=ex)
# Out:
# <Axes: ylabel='sex'>

# %%
sns.countplot(data=_df_0,x='sex',hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.catplot(kind='bar',data=_df_0,x='sex',y='survived',hue='pclass')
plt.grid(True)

# %%
sns.catplot(data=_df_0,x='sex',col='pclass',y='survived',kind='bar',height=3)

plt.show()

# %%
sns.catplot(data=_df_0,x='pclass',col='sex',y='survived',kind='bar',height=3)

plt.show()

# %%
sns.catplot(data=_df_0,x='sex',y='survived',hue='pclass',kind='point')
plt.show()

# %%
sns.catplot(data=_df_0,x='pclass',y='survived',hue='sex',kind='point')
plt.show()

# %%
sns.catplot(data=_df_0,x='sex',y='survived',kind='violin')
plt.grid(True)

# %%
sns.catplot(data=_df_0,kind='violin',x='sex',y='survived',col='pclass')

plt.show()

# %% [markdown]
# <!--Collapsible Headings-->
# ##  Age
#
# Legends
# - Survival - Survival (0 = No; 1 = Yes). Not included in test.csv file.
# - Pclass - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - Name - Name
# - Sex - Sex
# - Age - Age
# - Sibsp - Number of Siblings/Spouses Aboard
# - Parch - Number of Parents/Children Aboard
# - Ticket - Ticket Number
# - Fare - Passenger Fare
# - Deck - A/B/C/D/E/F/G
# - Embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# - Who - man/woman/child
# - Alive - yes/no
# - Alone - True/False

# %%
sns.histplot(_df_0['age'],kde=True,color='black')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.kdeplot(_df_0['age'], fill=True)
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.catplot(data=_df_0,x='sex',y='age',kind='box')

# %%
sns.catplot(data=_df_0,x='sex',y='age',kind='box',col='pclass')

# %%
sns.catplot(data=_df_0,x='pclass',y='age',kind='violin',hue='survived')

# %%
sns.catplot(data=_df_0,x='sex',y='age',kind='violin',hue='survived',col='pclass',split=True)

# %%
sns.catplot(x = 'pclass', y = 'age',hue='sex', data = _df_0,kind='violin')

# %%
sns.catplot(data=_df_0,x='survived',y='age',row='sex',col='pclass',kind='swarm',hue='survived',height=3)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning:
#
# 6.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning:
#
# 24.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %% [markdown]
# <!--Collapsible Headings-->
# ##  Fare
#
# Legends
# - Survival - Survival (0 = No; 1 = Yes). Not included in test.csv file.
# - Pclass - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - Name - Name
# - Sex - Sex
# - Age - Age
# - Sibsp - Number of Siblings/Spouses Aboard
# - Parch - Number of Parents/Children Aboard
# - Ticket - Ticket Number
# - Fare - Passenger Fare
# - Deck - A/B/C/D/E/F/G
# - Embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# - Who - man/woman/child
# - Alive - yes/no
# - Alone - True/False

# %%
sns.histplot(_df_0['fare'],kde=True,color='black',bins=30)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.kdeplot(_df_0['fare'],fill=True)
# Out:
# <Axes: xlabel='fare', ylabel='Density'>

# %%
sns.catplot(data=_df_0,x='sex',y='fare',kind='box')

# %%
sns.catplot(data=_df_0,x='pclass',y='fare',kind='box')

# %%
sns.catplot(data=_df_0,x='sex',y='fare',kind='box')

# %%
sns.catplot(data=_df_0,x='sex',y='age',kind='boxen',col='pclass',row='survived',sharex=False,height=2)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3201: UserWarning:
#
# Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.

# %%
sns.jointplot(data=_df_0,x='age',y='fare',height=4)

# %%
sns.relplot(data=_df_0,x='age',y='fare',col='pclass',row='survived',height=3)

# %% [markdown]
# <!--Collapsible Headings-->
# ##  Sibsp
#
# Legends
# - Survival - Survival (0 = No; 1 = Yes). Not included in test.csv file.
# - Pclass - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - Name - Name
# - Sex - Sex
# - Age - Age
# - Sibsp - Number of Siblings/Spouses Aboard
# - Parch - Number of Parents/Children Aboard
# - Ticket - Ticket Number
# - Fare - Passenger Fare
# - Deck - A/B/C/D/E/F/G
# - Embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# - Who - man/woman/child
# - Alive - yes/no
# - Alone - True/False

# %%
_df_0['sibsp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: sibsp, dtype: int64

# %%
_df_0.groupby(['sibsp'])['sex'].value_counts()
# Out:
# sibsp  sex
# 0      male      434
#        female    174
# 1      female    106
#        male      103
# 2      male       15
#        female     13
# 3      female     11
#        male        5
# 4      male       12
#        female      6
# 5      male        4
#        female      1
# 8      male        4
#        female      3
# Name: sex, dtype: int64

# %%
_df_0.groupby(['sibsp'])['sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='sibsp,sex'>

# %%
sns.countplot(data=_df_0,x='sibsp',hue='survived')
# Out:
# <Axes: xlabel='sibsp', ylabel='count'>

# %%
sns.catplot(data=_df_0,x='sibsp',y='survived',kind='bar')

# %%
sns.catplot(data=_df_0,x='sibsp',y='survived',kind='bar',col='sex')

# %%
sns.catplot(data=_df_0,x='sibsp',y='survived',kind='bar',col='pclass')

# %%
sns.catplot(data=_df_0,x='sibsp',y='survived',kind='point',col='pclass',height=3)

# %%
sns.catplot(data=_df_0,x='sibsp',y='survived',kind='point',hue='sex')

# %%
sns.catplot(data=_df_0,x='sibsp',y='fare',kind='boxen',col='pclass',row='sex',height=3,sharex=False)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3201: UserWarning:
#
# Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.

# %%
sns.catplot(data=_df_0,x='sibsp',y='fare',kind='point',col='pclass',row='sex',height=3,sharex=False)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3201: UserWarning:
#
# Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.

# %% [markdown]
# <!--Collapsible Headings-->
# ##  Parch
#
# Legends
# - Survival - Survival (0 = No; 1 = Yes). Not included in test.csv file.
# - Pclass - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - Name - Name
# - Sex - Sex
# - Age - Age
# - Sibsp - Number of Siblings/Spouses Aboard
# - Parch - Number of Parents/Children Aboard
# - Ticket - Ticket Number
# - Fare - Passenger Fare
# - Deck - A/B/C/D/E/F/G
# - Embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# - Who - man/woman/child
# - Alive - yes/no
# - Alone - True/False

# %%
_df_0['parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: parch, dtype: int64

# %%
sns.countplot(_df_0,x='parch')
# Out:
# <Axes: xlabel='parch', ylabel='count'>

# %%
sns.catplot(data=_df_0,kind='bar',x='parch',y='fare',col='pclass',row='sex',height=3,sharex=False,sharey=False)
plt.tight_layout()
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3201: UserWarning:
#
# Setting `sharex=False` with `color=None` may cause different levels of the `x` variable to share colors. This will change in a future version.

# %%
_df_0['embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
sns.countplot(data=_df_0,x='embarked')
# Out:
# <Axes: xlabel='embarked', ylabel='count'>

# %%
sns.countplot(data=_df_0,x='embarked',hue='pclass')
# Out:
# <Axes: xlabel='embarked', ylabel='count'>

# %%
sns.countplot(data=_df_0,x='embarked',hue='survived',order=['C','S','Q'],hue_order=[1,0])
# Out:
# <Axes: xlabel='embarked', ylabel='count'>

# %%
sns.catplot(data=_df_0,kind='bar',x='embarked',y='survived')

# %%
sns.catplot(data=_df_0,kind='bar',x='embarked',y='survived',col='sex')

# %% [markdown]
# <!--Collapsible Headings-->
# ## Who
#
# Legends
# - Survival - Survival (0 = No; 1 = Yes). Not included in test.csv file.
# - Pclass - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - Name - Name
# - Sex - Sex
# - Age - Age
# - Sibsp - Number of Siblings/Spouses Aboard
# - Parch - Number of Parents/Children Aboard
# - Ticket - Ticket Number
# - Fare - Passenger Fare
# - Deck - A/B/C/D/E/F/G
# - Embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# - Who - man/woman/child
# - Alive - yes/no
# - Alone - True/False

# %%
_df_0['who'].value_counts()
# Out:
# man      537
# woman    271
# child     83
# Name: who, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(3, 3))
_df_0['who'].value_counts().plot.pie(autopct='%.3f',ax=ax)
# Out:
# <Axes: ylabel='who'>

# %%
fig, ax = plt.subplots(figsize=(3,3 ))
sns.countplot(data=_df_0,x='who',ax=ax)
# Out:
# <Axes: xlabel='who', ylabel='count'>

# %%
sns.catplot(data=_df_0,x='who',y='survived',kind='bar',height=3)

# %%
sns.catplot(data=_df_0,x='who',y='survived',col='pclass',kind='bar',height=3)

# %%
sns.catplot(data=_df_0,x='who',y='survived',col='parch',kind='bar',height=3,col_wrap=4)

# %% [markdown]
# #this is a git test .
